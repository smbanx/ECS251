# %%
import os
import time
import torch
import numpy as np
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertModel
import matplotlib.pyplot as plt
from liburing import (
    O_RDONLY, AT_FDCWD, iovec, io_uring, io_uring_get_sqe,
    io_uring_prep_openat, io_uring_prep_read, io_uring_prep_close,
    io_uring_submit, io_uring_wait_cqe, io_uring_cqe_seen,
    io_uring_cqe, io_uring_queue_init, io_uring_queue_exit,
    io_uring_sqe_set_data64, trap_error
)


class BenchmarkConfig:
    """Configuration for the benchmark"""
    def __init__(self, 
                 data_dir="./benchmark_data",
                 num_files=1000,
                 file_size=4096,  # 4KB per file
                 batch_size=32,
                 num_workers=4,
                 queue_depth=128,
                 num_epochs=3,
                 seed=42):
        self.data_dir = data_dir
        self.num_files = num_files
        self.file_size = file_size
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.queue_depth = queue_depth
        self.num_epochs = num_epochs
        self.seed = seed
        
        # Create output directory if it doesn't exist
        os.makedirs(data_dir, exist_ok=True)


def generate_benchmark_data(config):
    """Generate synthetic data files for benchmarking"""
    print(f"Generating {config.num_files} benchmark files...")
    
    # Set random seed for reproducibility
    np.random.seed(config.seed)
    
    for i in range(config.num_files):
        # Generate random data (simulating text data)
        data = np.random.randint(0, 256, size=config.file_size, dtype=np.uint8)
        
        # Convert to bytes and save to file
        with open(os.path.join(config.data_dir, f"file_{i}.txt"), "wb") as f:
            f.write(data.tobytes())
    
    print("Benchmark data generation complete!")


class VanillaDataset(Dataset):
    """Standard PyTorch dataset using regular file I/O"""
    def __init__(self, data_dir, file_list, tokenizer, max_length=128):
        self.data_dir = data_dir
        self.file_list = file_list
        self.tokenizer = tokenizer
        self.max_length = max_length
    
    def __len__(self):
        return len(self.file_list)
    
    def __getitem__(self, idx):
        # Load file using regular I/O
        file_path = os.path.join(self.data_dir, self.file_list[idx])
        with open(file_path, 'rb') as f:
            content = f.read()
        
        # Convert bytes to text (assuming UTF-8, but handling errors)
        text = content.decode('utf-8', errors='replace')
        
        # Tokenize text
        encoded = self.tokenizer(
            text, 
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )
        
        # Return the encoded tokens
        return {
            'input_ids': encoded['input_ids'].squeeze(),
            'attention_mask': encoded['attention_mask'].squeeze(),
        }


class IoUringHelper:
    """Helper class for io_uring operations"""
    def __init__(self, queue_depth=128):
        self.ring = io_uring()
        self.cqe = io_uring_cqe()
        self.queue_depth = queue_depth
        io_uring_queue_init(queue_depth, self.ring, 0)
    
    def __del__(self):
        """Clean up resources"""
        io_uring_queue_exit(self.ring)
        
    def open_file(self, path):
        """Open a file using io_uring"""
        _path = path if isinstance(path, bytes) else str(path).encode()
        sqe = io_uring_get_sqe(self.ring)
        io_uring_prep_openat(sqe, AT_FDCWD, _path, O_RDONLY, 0)
        io_uring_sqe_set_data64(sqe, 1)
        return self._submit_and_wait()
    
    def read_file(self, fd, length):
        """Read data from file using io_uring"""
        iov = iovec(bytearray(length))
        sqe = io_uring_get_sqe(self.ring)
        io_uring_prep_read(sqe, fd, iov.iov_base, iov.iov_len, 0)
        io_uring_sqe_set_data64(sqe, 2)
        self._submit_and_wait()
        return iov.iov_base
    
    def close_file(self, fd):
        """Close a file using io_uring"""
        sqe = io_uring_get_sqe(self.ring)
        io_uring_prep_close(sqe, fd)
        io_uring_sqe_set_data64(sqe, 3)
        self._submit_and_wait()
    
    def _submit_and_wait(self):
        """Submit operation and wait for completion"""
        io_uring_submit(self.ring)
        io_uring_wait_cqe(self.ring, self.cqe)
        result = trap_error(self.cqe.res)
        io_uring_cqe_seen(self.ring, self.cqe)
        return result


class IoUringDataset(Dataset):
    """Dataset implementation using io_uring for async I/O"""
    def __init__(self, data_dir, file_list, tokenizer, max_length=128, queue_depth=128):
        self.data_dir = data_dir
        self.file_list = file_list
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.io_helper = IoUringHelper(queue_depth)
    
    def __len__(self):
        return len(self.file_list)
    
    def __getitem__(self, idx):
        # Get file path
        file_path = os.path.join(self.data_dir, self.file_list[idx])
        
        # Read file using io_uring
        try:
            # Open file
            fd = self.io_helper.open_file(file_path)
            
            # Get file size (we could optimize this in a real implementation)
            file_size = os.path.getsize(file_path)
            
            # Read file content
            content = self.io_helper.read_file(fd, file_size)
            
            # Close file
            self.io_helper.close_file(fd)
            
            # Convert bytes to text
            text = content.decode('utf-8', errors='replace')
            
            # Tokenize text
            encoded = self.tokenizer(
                text, 
                max_length=self.max_length,
                padding='max_length',
                truncation=True,
                return_tensors='pt'
            )
            
            return {
                'input_ids': encoded['input_ids'].squeeze(),
                'attention_mask': encoded['attention_mask'].squeeze(),
            }
        except Exception as e:
            print(f"Error processing file {file_path}: {e}")
            # Return empty tensors in case of error
            return {
                'input_ids': torch.zeros(self.max_length, dtype=torch.long),
                'attention_mask': torch.zeros(self.max_length, dtype=torch.long),
            }


def run_benchmark(config, dataloader, model, device, desc=""):
    """Run benchmark for a specific dataloader implementation"""
    start_time = time.time()
    total_batches = 0
    
    # Track timing for each phase
    io_times = []
    compute_times = []
    
    print(f"\nRunning benchmark for {desc}...")
    
    for epoch in range(config.num_epochs):
        epoch_start = time.time()
        
        for batch_idx, batch in enumerate(dataloader):
            # Track I/O time (time to get the batch)
            io_end = time.time()
            io_time = io_end - (compute_end if batch_idx > 0 else epoch_start)
            io_times.append(io_time)
            
            # Move to device and run model (compute)
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            
            # Forward pass
            with torch.no_grad():
                outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            
            # Track compute time
            compute_end = time.time()
            compute_time = compute_end - io_end
            compute_times.append(compute_time)
            
            total_batches += 1
            
            if batch_idx % 10 == 0:
                print(f"Epoch {epoch+1}/{config.num_epochs}, Batch {batch_idx}/{len(dataloader)}")
    
    total_time = time.time() - start_time
    avg_batch_time = total_time / total_batches
    avg_io_time = np.mean(io_times)
    avg_compute_time = np.mean(compute_times)
    
    results = {
        'total_time': total_time,
        'avg_batch_time': avg_batch_time,
        'avg_io_time': avg_io_time,
        'avg_compute_time': avg_compute_time,
        'io_times': io_times,
        'compute_times': compute_times
    }
    
    print(f"Benchmark results for {desc}:")
    print(f"  Total time: {total_time:.4f}s")
    print(f"  Average batch time: {avg_batch_time:.4f}s")
    print(f"  Average I/O time: {avg_io_time:.4f}s")
    print(f"  Average compute time: {avg_compute_time:.4f}s")
    print(f"  I/O percentage: {(avg_io_time / (avg_io_time + avg_compute_time)) * 100:.2f}%")
    
    return results


def plot_results(vanilla_results, iouring_results):
    """Plot comparison of benchmark results"""
    plt.figure(figsize=(15, 10))
    
    # Plot 1: Total times comparison
    plt.subplot(2, 2, 1)
    times = [
        vanilla_results['total_time'],
        iouring_results['total_time']
    ]
    plt.bar(['Vanilla', 'io_uring'], times)
    plt.title('Total Execution Time (s)')
    plt.ylabel('Time (seconds)')
    
    # Plot 2: Average batch times
    plt.subplot(2, 2, 2)
    avg_times = [
        vanilla_results['avg_batch_time'],
        iouring_results['avg_batch_time']
    ]
    plt.bar(['Vanilla', 'io_uring'], avg_times)
    plt.title('Average Batch Processing Time (s)')
    plt.ylabel('Time (seconds)')
    
    # Plot 3: I/O vs Compute breakdown
    plt.subplot(2, 2, 3)
    labels = ['I/O', 'Compute']
    vanilla_breakdown = [vanilla_results['avg_io_time'], vanilla_results['avg_compute_time']]
    iouring_breakdown = [iouring_results['avg_io_time'], iouring_results['avg_compute_time']]
    
    x = np.arange(len(labels))
    width = 0.35
    
    plt.bar(x - width/2, vanilla_breakdown, width, label='Vanilla')
    plt.bar(x + width/2, iouring_breakdown, width, label='io_uring')
    plt.xlabel('Phase')
    plt.ylabel('Time (seconds)')
    plt.title('I/O vs Compute Time')
    plt.xticks(x, labels)
    plt.legend()
    
    # Plot 4: Speedup ratio
    plt.subplot(2, 2, 4)
    io_speedup = vanilla_results['avg_io_time'] / iouring_results['avg_io_time']
    total_speedup = vanilla_results['avg_batch_time'] / iouring_results['avg_batch_time']
    
    plt.bar(['I/O Speedup', 'Total Speedup'], [io_speedup, total_speedup])
    plt.axhline(y=1.0, color='r', linestyle='-', alpha=0.3)
    plt.title('Speedup Ratio (Vanilla / io_uring)')
    plt.ylabel('Ratio')
    
    plt.tight_layout()
    plt.savefig('io_uring_benchmark_results.png')
    plt.show()


def main():
    # Initialize benchmark configuration
    config = BenchmarkConfig()
    
    # Generate benchmark data if needed
    if not os.path.exists(config.data_dir) or len(os.listdir(config.data_dir)) < config.num_files:
        generate_benchmark_data(config)
    
    # Get list of files
    file_list = [f for f in os.listdir(config.data_dir) if f.endswith('.txt')]
    print(f"Found {len(file_list)} files for benchmarking")
    
    # Initialize tokenizer and model
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = BertModel.from_pretrained('bert-base-uncased')
    
    # Set device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    model.eval()
    
    print(f"Using device: {device}")
    
    # Create datasets
    vanilla_dataset = VanillaDataset(config.data_dir, file_list, tokenizer)
    iouring_dataset = IoUringDataset(config.data_dir, file_list, tokenizer, queue_depth=config.queue_depth)
    
    # Create dataloaders
    vanilla_dataloader = DataLoader(
        vanilla_dataset,
        batch_size=config.batch_size,
        shuffle=True,
        num_workers=config.num_workers,
        pin_memory=(device.type == 'cuda')
    )
    
    # Note: For IoUringDataset, we need to be careful with num_workers
    # Each worker will create its own IoUringHelper instance
    iouring_dataloader = DataLoader(
        iouring_dataset,
        batch_size=config.batch_size,
        shuffle=True,
        num_workers=config.num_workers,
        pin_memory=(device.type == 'cuda')
    )
    
    # Run benchmarks
    vanilla_results = run_benchmark(config, vanilla_dataloader, model, device, "Vanilla DataLoader")
    iouring_results = run_benchmark(config, iouring_dataloader, model, device, "io_uring DataLoader")
    
    # Plot results
    plot_results(vanilla_results, iouring_results)
    
    # Print improvement summary
    io_improvement = (vanilla_results['avg_io_time'] - iouring_results['avg_io_time']) / vanilla_results['avg_io_time'] * 100
    total_improvement = (vanilla_results['avg_batch_time'] - iouring_results['avg_batch_time']) / vanilla_results['avg_batch_time'] * 100
    
    print("\nPerformance Improvement Summary:")
    print(f"  I/O Time Improvement: {io_improvement:.2f}%")
    print(f"  Total Time Improvement: {total_improvement:.2f}%")
    
    # Clean up (optional)
    # import shutil
    # shutil.rmtree(config.data_dir)


if __name__ == "__main__":
    main()
# Out:
# Generating 1000 benchmark files...
# Benchmark data generation complete!
# Found 1000 files for benchmarking
# Using device: cpu
#
# Running benchmark for Vanilla DataLoader...
# Epoch 1/3, Batch 0/32
# Epoch 1/3, Batch 10/32
# Epoch 1/3, Batch 20/32
# Epoch 1/3, Batch 30/32
# Epoch 2/3, Batch 0/32
# Epoch 2/3, Batch 10/32
# Epoch 2/3, Batch 20/32
# Epoch 2/3, Batch 30/32
# Epoch 3/3, Batch 0/32
# Epoch 3/3, Batch 10/32
# Epoch 3/3, Batch 20/32
# Epoch 3/3, Batch 30/32
# Benchmark results for Vanilla DataLoader:
#   Total time: 1198.9607s
#   Average batch time: 12.4892s
#   Average I/O time: 0.0614s
#   Average compute time: 12.4262s
#   I/O percentage: 0.49%
#
# Running benchmark for io_uring DataLoader...
# Error processing file ./benchmark_data/file_313.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_585.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_406.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_454.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_427.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_321.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_290.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_338.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_640.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_532.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_15.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_681.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_608.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_337.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_185.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_105.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_489.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_250.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_263.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_184.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_646.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_420.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_749.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_986.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_370.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_947.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_45.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_55.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_969.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_203.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_679.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_213.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_990.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_425.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_676.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_867.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_220.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_24.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_179.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_877.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_237.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_692.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_469.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_507.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_48.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_885.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_801.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_157.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_564.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_333.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_354.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_690.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_649.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_887.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_318.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_8.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_937.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_696.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_448.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_261.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_573.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_912.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_781.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_788.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_956.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_718.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_754.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_145.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_62.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_468.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_567.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_874.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_410.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_958.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_405.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_625.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_831.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_397.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_375.txt: expected bytes, __common_define__ found
#
#
#
# Error processing file ./benchmark_data/file_656.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_898.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_168.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_94.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_890.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_230.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_747.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_387.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_390.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_722.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_139.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_792.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_352.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_842.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_701.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_119.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_886.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_604.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_524.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_256.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_627.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_291.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_458.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_77.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_460.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_466.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_91.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_823.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_286.txt: expected bytes, __common_define__ found
#
#
#
# Error processing file ./benchmark_data/file_70.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_725.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_537.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_852.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_497.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_349.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_27.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_408.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_614.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_819.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_418.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_976.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_99.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_717.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_529.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_496.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_192.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_920.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_791.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_422.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_753.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_266.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_143.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_988.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_595.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_209.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_107.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_226.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_207.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_674.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_493.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_5.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_560.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_767.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_572.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_850.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_641.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_545.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_611.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_829.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_206.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_304.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_807.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_361.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_764.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_492.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_675.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_672.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_643.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_233.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_846.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_505.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_116.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_670.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_766.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_409.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_785.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_533.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_80.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_194.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_925.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_292.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_148.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_980.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_741.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_357.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_916.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_645.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_381.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_271.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_693.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_534.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_282.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_131.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_981.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_883.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_517.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_104.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_746.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_423.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_868.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_720.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_300.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_847.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_797.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_921.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_444.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_442.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_843.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_239.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_134.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_520.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_236.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_876.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_684.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_296.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_698.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_965.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_392.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_289.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_554.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_702.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_523.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_992.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_20.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_872.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_536.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_166.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_299.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_21.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_437.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_839.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_713.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_438.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_952.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_892.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_81.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_949.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_360.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_870.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_946.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_336.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_513.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_491.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_790.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_212.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_301.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_475.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_936.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_329.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_543.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_199.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_755.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_391.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_419.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_84.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_450.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_900.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_917.txt: expected bytes, __common_define__ found
#
#
# Error processing file ./benchmark_data/file_195.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_859.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_113.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_433.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_259.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_997.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_557.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_6.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_499.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_411.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_765.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_356.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_414.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_125.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_620.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_895.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_673.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_379.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_561.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_778.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_896.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_83.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_88.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_904.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_154.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_267.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_848.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_699.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_548.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_602.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_380.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_362.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_510.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_798.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_853.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_757.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_984.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_665.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_293.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_774.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_171.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_516.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_2.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_728.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_443.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_822.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_85.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_23.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_400.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_28.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_477.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_44.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_371.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_38.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_634.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_526.txt: expected bytes, __common_define__ found
# Epoch 1/3, Batch 0/32
# Error processing file ./benchmark_data/file_218.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_404.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_335.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_881.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_601.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_884.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_982.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_358.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_783.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_710.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_558.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_297.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_840.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_837.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_918.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_234.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_258.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_685.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_187.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_869.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_899.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_927.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_61.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_973.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_137.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_398.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_114.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_518.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_569.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_363.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_257.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_303.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_994.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_808.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_542.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_970.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_759.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_825.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_12.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_613.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_127.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_769.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_445.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_473.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_915.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_578.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_470.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_771.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_738.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_907.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_132.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_447.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_464.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_922.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_865.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_355.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_796.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_549.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_706.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_637.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_327.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_242.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_33.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_328.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_863.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_721.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_117.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_365.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_929.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_170.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_71.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_13.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_793.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_196.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_719.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_204.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_317.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_743.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_278.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_761.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_225.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_663.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_182.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_222.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_472.txt: expected bytes, __common_define__ foundError processing file ./benchmark_data/file_181.txt: expected bytes, __common_define__ found
#
# Error processing file ./benchmark_data/file_373.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_782.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_275.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_483.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_39.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_911.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_802.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_252.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_172.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_417.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_776.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_330.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_731.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_942.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_671.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_506.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_609.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_428.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_583.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_559.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_726.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_565.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_325.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_745.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_546.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_991.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_246.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_811.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_153.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_552.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_305.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_775.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_610.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_948.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_845.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_962.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_306.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_514.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_228.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_210.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_183.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_750.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_462.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_359.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_733.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_208.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_875.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_849.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_440.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_308.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_407.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_586.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_273.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_129.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_322.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_612.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_162.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_479.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_893.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_395.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_342.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_939.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_525.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_50.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_276.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_606.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_429.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_123.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_140.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_605.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_124.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_112.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_307.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_794.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_57.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_231.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_215.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_315.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_668.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_862.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_108.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_933.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_205.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_130.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_36.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_156.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_449.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_957.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_855.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_787.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_320.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_255.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_652.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_389.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_494.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_772.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_65.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_943.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_817.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_729.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_935.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_864.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_386.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_72.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_515.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_584.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_686.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_716.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_629.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_660.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_662.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_809.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_280.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_740.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_270.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_919.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_111.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_860.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_350.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_805.txt: expected bytes, __common_define__ found
# ...
# Error processing file ./benchmark_data/file_849.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_413.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_860.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_145.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_858.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_128.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_947.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_182.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_363.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_841.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_221.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_290.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_573.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_549.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_215.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_246.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_640.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_665.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_574.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_596.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_879.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_493.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_201.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_924.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_855.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_724.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_840.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_127.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_120.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_781.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_880.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_516.txt: expected bytes, __common_define__ found
# Error processing file ./benchmark_data/file_608.txt: expected bytes, __common_define__ found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 380
#     374     # Clean up (optional)
#     375     # import shutil
#     376     # shutil.rmtree(config.data_dir)
#     379 if __name__ == "__main__":
# --> 380     main()
#
# Cell In[1], line 361, in main()
#     359 # Run benchmarks
#     360 vanilla_results = run_benchmark(config, vanilla_dataloader, model, device, "Vanilla DataLoader")
# --> 361 iouring_results = run_benchmark(config, iouring_dataloader, model, device, "io_uring DataLoader")
#     363 # Plot results
#     364 plot_results(vanilla_results, iouring_results)
#
# Cell In[1], line 221, in run_benchmark(config, dataloader, model, device, desc)
#     219 # Forward pass
#     220 with torch.no_grad():
# --> 221     outputs = model(input_ids=input_ids, attention_mask=attention_mask)
#     223 # Track compute time
#     224 compute_end = time.time()
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:1142, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1135 # Prepare head mask if needed
#    1136 # 1.0 in head_mask indicate we keep the head
#    1137 # attention_probs has shape bsz x n_heads x N x N
#    1138 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1139 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1140 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1142 encoder_outputs = self.encoder(
#    1143     embedding_output,
#    1144     attention_mask=extended_attention_mask,
#    1145     head_mask=head_mask,
#    1146     encoder_hidden_states=encoder_hidden_states,
#    1147     encoder_attention_mask=encoder_extended_attention_mask,
#    1148     past_key_values=past_key_values,
#    1149     use_cache=use_cache,
#    1150     output_attentions=output_attentions,
#    1151     output_hidden_states=output_hidden_states,
#    1152     return_dict=return_dict,
#    1153 )
#    1154 sequence_output = encoder_outputs[0]
#    1155 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:695, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     684     layer_outputs = self._gradient_checkpointing_func(
#     685         layer_module.__call__,
#     686         hidden_states,
#    (...)
#     692         output_attentions,
#     693     )
#     694 else:
# --> 695     layer_outputs = layer_module(
#     696         hidden_states,
#     697         attention_mask,
#     698         layer_head_mask,
#     699         encoder_hidden_states,
#     700         encoder_attention_mask,
#     701         past_key_value,
#     702         output_attentions,
#     703     )
#     705 hidden_states = layer_outputs[0]
#     706 if use_cache:
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:585, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     573 def forward(
#     574     self,
#     575     hidden_states: torch.Tensor,
#    (...)
#     582 ) -> Tuple[torch.Tensor]:
#     583     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     584     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 585     self_attention_outputs = self.attention(
#     586         hidden_states,
#     587         attention_mask,
#     588         head_mask,
#     589         output_attentions=output_attentions,
#     590         past_key_value=self_attn_past_key_value,
#     591     )
#     592     attention_output = self_attention_outputs[0]
#     594     # if decoder, the last output is tuple of self-attn cache
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:524, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     505 def forward(
#     506     self,
#     507     hidden_states: torch.Tensor,
#    (...)
#     513     output_attentions: Optional[bool] = False,
#     514 ) -> Tuple[torch.Tensor]:
#     515     self_outputs = self.self(
#     516         hidden_states,
#     517         attention_mask,
#    (...)
#     522         output_attentions,
#     523     )
# --> 524     attention_output = self.output(self_outputs[0], hidden_states)
#     525     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#     526     return outputs
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:466, in BertSelfOutput.forward(self, hidden_states, input_tensor)
#     465 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 466     hidden_states = self.dense(hidden_states)
#     467     hidden_states = self.dropout(hidden_states)
#     468     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /mnt/c/Users/kwabe/My Documents/UC Davis MSCS/UCD MSCS/Year 1/Winter 2025/Operating Systems/OS Final Project/osenv/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
